# %%
import pandas as pd
from scipy.spatial.distance import cdist


data1 = {'Lat': pd.Series([50.6373473,50.63740441,50.63744285,50.63737839,50.6376054,50.6375896,50.6374239,50.6374404]),
         'Lon': pd.Series([3.075029928,3.075068636,3.074951754,3.074913884,3.0750528,3.0751209,3.0750246,3.0749554]),
         'Zone': pd.Series(['A','A','A','A','B','B','B','B'])}

data2 = {'Lat': pd.Series([50.6375524099,50.6375714407]),
         'Lon': pd.Series([3.07507914474,3.07508201591])}


def closest_point(point, points):
    """ Find closest point from a list of points. """
    return points[cdist([point], points).argmin()]

def match_value(df, col1, x, col2):
    """ Match value x from col1 row to value in col2. """
    return df[df[col1] == x][col2].values[0]


df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

df1['point'] = [(x, y) for x,y in zip(df1['Lat'], df1['Lon'])]
df2['point'] = [(x, y) for x,y in zip(df2['Lat'], df2['Lon'])]

df2['closest'] = [closest_point(x, list(df1['point'])) for x in df2['point']]
df2['zone'] = [match_value(df1, 'point', x, 'Zone') for x in df2['closest']]

df2
# Out:
#          Lat       Lon                           point  \
# 0  50.637552  3.075079  (50.6375524099, 3.07507914474)
# 1  50.637571  3.075082  (50.6375714407, 3.07508201591)
#
#                    closest zone
# 0  (50.6375896, 3.0751209)    B
# 1  (50.6375896, 3.0751209)    B

# %%
import xarray as xr
ds_m = xr.open_dataset('monthy.nc')
df_m = ds_m.to_dataframe().reset_index()
df_m.head()
# Out:
#      lon   lat  time  CLOUD_OD_11  ALLSKY_SFC_SW_DWN_19  CLOUD_OD_02  \
# 0 -179.5  89.5   0.0     4.859375              0.000000     5.304688
# 1 -179.5  89.5   1.0     4.375000              0.000000     4.335938
# 2 -179.5  89.5   2.0     3.625000             11.875000     3.664062
# 3 -179.5  89.5   3.0     2.398438            170.171875     2.539062
# 4 -179.5  89.5   4.0     2.789062            319.648438     2.906250
#
#    CLOUD_OD_05  CLOUD_AMT_11  ALLSKY_SFC_SW_DWN_04  ALLSKY_SFC_SW_DWN_01  ...  \
# 0     4.562500     57.101562              0.000000              0.000000  ...
# 1     4.195312     76.171875              0.000000              0.000000  ...
# 2     3.312500     56.453125             11.656250             12.734375  ...
# 3     2.007812     64.632812            163.648438            156.687500  ...
# 4     3.117188     82.468750            296.093750            317.906250  ...
#
#    CLOUD_OD_17  CLOUD_AMT_09  ALLSKY_SFC_SW_DWN_05  ALLSKY_SFC_SW_DWN_11  \
# 0     4.492188     55.132812              0.000000              0.000000
# 1     4.281250     78.343750              0.000000              0.000000
# 2     3.500000     55.585938             11.054688              8.960938
# 3     2.281250     67.929688            166.812500            151.695312
# 4     3.679688     80.421875            303.375000            289.468750
#
#    ALLSKY_SFC_SW_DWN_21  CLOUD_AMT_15  ALLSKY_SFC_SW_DWN_15  CLOUD_OD_07  \
# 0              0.000000     61.093750              0.000000     4.492188
# 1              0.000000     75.562500              0.000000     4.484375
# 2             13.171875     61.062500              9.148438     3.539062
# 3            174.796875     67.070312            159.531250     1.781250
# 4            308.484375     81.960938            294.898438     3.054688
#
#    ALLSKY_SFC_SW_DWN_13  ALLSKY_SFC_SW_DWN_16
# 0              0.000000              0.000000
# 1              0.000000              0.000000
# 2              8.507812              9.906250
# 3            148.789062            166.062500
# 4            293.960938            309.289062
#
# [5 rows x 75 columns]

# %%
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 842400 entries, (-179.5, 89.5, 0.0) to (179.5, -89.5, nan)
# Data columns (total 72 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   CLOUD_OD_11           842400 non-null  float64
#  1   ALLSKY_SFC_SW_DWN_19  842400 non-null  float64
#  2   CLOUD_OD_02           842400 non-null  float64
#  3   CLOUD_OD_05           842400 non-null  float64
#  4   CLOUD_AMT_11          842400 non-null  float64
#  5   ALLSKY_SFC_SW_DWN_04  842400 non-null  float64
#  6   ALLSKY_SFC_SW_DWN_01  842400 non-null  float64
#  7   CLOUD_OD_12           842400 non-null  float64
#  8   ALLSKY_SFC_SW_DWN_18  842400 non-null  float64
#  9   CLOUD_OD_13           842400 non-null  float64
#  10  CLOUD_OD_15           842400 non-null  float64
#  11  CLOUD_OD_09           842400 non-null  float64
#  12  ALLSKY_SFC_SW_DWN_10  842400 non-null  float64
#  13  CLOUD_OD_19           842400 non-null  float64
#  14  CLOUD_AMT_13          842400 non-null  float64
#  15  CLOUD_OD_21           842400 non-null  float64
#  16  CLOUD_AMT_22          842400 non-null  float64
#  17  CLOUD_AMT_08          842400 non-null  float64
#  18  CLOUD_AMT_21          842400 non-null  float64
#  19  CLOUD_OD_22           842400 non-null  float64
#  20  CLOUD_AMT_20          842400 non-null  float64
#  21  ALLSKY_SFC_SW_DWN_08  842400 non-null  float64
#  22  ALLSKY_SFC_SW_DWN_17  842400 non-null  float64
#  23  CLOUD_OD_14           842400 non-null  float64
#  24  ALLSKY_SFC_SW_DWN_03  842400 non-null  float64
#  25  ALLSKY_SFC_SW_DWN_09  842400 non-null  float64
#  26  ALLSKY_SFC_SW_DWN_20  842400 non-null  float64
#  27  CLOUD_AMT_12          842400 non-null  float64
#  28  ALLSKY_SFC_SW_DWN_22  842400 non-null  float64
#  29  CLOUD_AMT_18          842400 non-null  float64
#  30  CLOUD_AMT_16          842400 non-null  float64
#  31  ALLSKY_SFC_SW_DWN_23  842400 non-null  float64
#  32  CLOUD_OD_18           842400 non-null  float64
#  33  CLOUD_AMT_23          842400 non-null  float64
#  34  CLOUD_OD_08           842400 non-null  float64
#  35  CLOUD_AMT_03          842400 non-null  float64
#  36  CLOUD_AMT_06          842400 non-null  float64
#  37  ALLSKY_SFC_SW_DWN_00  842400 non-null  float64
#  38  CLOUD_AMT_04          842400 non-null  float64
#  39  CLOUD_AMT_01          842400 non-null  float64
#  40  CLOUD_AMT_02          842400 non-null  float64
#  41  ALLSKY_SFC_SW_DWN_14  842400 non-null  float64
#  42  CLOUD_OD_03           842400 non-null  float64
#  43  CLOUD_AMT_14          842400 non-null  float64
#  44  CLOUD_OD_01           842400 non-null  float64
#  45  ALLSKY_SFC_SW_DWN_02  842400 non-null  float64
#  46  CLOUD_AMT_19          842400 non-null  float64
#  47  ALLSKY_SFC_SW_DWN_12  842400 non-null  float64
#  48  CLOUD_OD_20           842400 non-null  float64
#  49  CLOUD_AMT_10          842400 non-null  float64
#  50  CLOUD_OD_00           842400 non-null  float64
#  51  CLOUD_AMT_17          842400 non-null  float64
#  52  CLOUD_OD_16           842400 non-null  float64
#  53  CLOUD_OD_04           842400 non-null  float64
#  54  CLOUD_OD_06           842400 non-null  float64
#  55  CLOUD_OD_10           842400 non-null  float64
#  56  ALLSKY_SFC_SW_DWN_06  842400 non-null  float64
#  57  CLOUD_OD_23           842400 non-null  float64
#  58  CLOUD_AMT_00          842400 non-null  float64
#  59  ALLSKY_SFC_SW_DWN_07  842400 non-null  float64
#  60  CLOUD_AMT_05          842400 non-null  float64
#  61  CLOUD_AMT_07          842400 non-null  float64
#  62  CLOUD_OD_17           842400 non-null  float64
#  63  CLOUD_AMT_09          842400 non-null  float64
#  64  ALLSKY_SFC_SW_DWN_05  842400 non-null  float64
#  65  ALLSKY_SFC_SW_DWN_11  842400 non-null  float64
#  66  ALLSKY_SFC_SW_DWN_21  842400 non-null  float64
#  67  CLOUD_AMT_15          842400 non-null  float64
#  68  ALLSKY_SFC_SW_DWN_15  842400 non-null  float64
#  69  CLOUD_OD_07           842400 non-null  float64
#  70  ALLSKY_SFC_SW_DWN_13  842400 non-null  float64
#  71  ALLSKY_SFC_SW_DWN_16  842400 non-null  float64
# dtypes: float64(72)
# memory usage: 466.8 MB

# %%
zones_df = pd.read_csv("worldcities.csv", sep=",")
zones_df.head()
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name  \
# 0      Tokyo      Tokyo  35.6897  139.6922      Japan   JP  JPN        Tōkyō
# 1    Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi  28.6100   77.2300      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id
# 0  primary  37732000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  26940000.0  1156237133
# 4    admin  24973000.0  1356226629

# %%
# convert to GeoDataFrame
df1 = gpd.GeoDataFrame(df_m, geometry=gpd.points_from_xy(df_m.lon, df_m.lat))
df2 = gpd.GeoDataFrame(zones_df, geometry=gpd.points_from_xy(zones_df.lng, zones_df.lat))

# aggregate & merge
merged = gpd.sjoin_nearest(df1, df2) #, how = 'inner', max_distance = 1000 , lsuffix = 'left', rsuffix = 'right', distance_col = "dist")



# output
# output_columns = ['Lat', 'Lon', 'city']
# merged[output_columns]
merged
# Out:
#           lon  lat_left  time  CLOUD_OD_11  ALLSKY_SFC_SW_DWN_19  CLOUD_OD_02  \
# 0      -179.5      89.5   0.0     4.859375              0.000000     5.304688
# 1      -179.5      89.5   1.0     4.375000              0.000000     4.335938
# 2      -179.5      89.5   2.0     3.625000             11.875000     3.664062
# 3      -179.5      89.5   3.0     2.398438            170.171875     2.539062
# 4      -179.5      89.5   4.0     2.789062            319.648438     2.906250
# ...       ...       ...   ...          ...                   ...          ...
# 841589  179.5     -27.5   8.0     3.570312            202.906250     4.640625
# 841590  179.5     -27.5   9.0     2.406250            289.531250     4.390625
# 841591  179.5     -27.5  10.0     2.835938            393.062500     4.710938
# 841592  179.5     -27.5  11.0     3.656250            351.601562     8.671875
# 841593  179.5     -27.5   NaN     2.648438            200.367188     4.929688
#
#         CLOUD_OD_05  CLOUD_AMT_11  ALLSKY_SFC_SW_DWN_04  ALLSKY_SFC_SW_DWN_01  \
# 0          4.562500     57.101562              0.000000              0.000000
# 1          4.195312     76.171875              0.000000              0.000000
# 2          3.312500     56.453125             11.656250             12.734375
# 3          2.007812     64.632812            163.648438            156.687500
# 4          3.117188     82.468750            296.093750            317.906250
# ...             ...           ...                   ...                   ...
# 841589     2.828125     69.875000            202.242188            674.781250
# 841590     3.960938     78.148438            223.351562            667.093750
# 841591    11.640625     68.781250            287.500000            759.406250
# 841592    13.960938     81.117188            280.523438            705.460938
# 841593     5.070312     71.953125            211.406250            636.257812
#
#         ...  city_ascii  lat_right       lng  country  iso2  iso3  \
# 0       ...    Zvezdnyy    70.9333 -179.6000   Russia    RU   RUS
# 1       ...    Zvezdnyy    70.9333 -179.6000   Russia    RU   RUS
# 2       ...    Zvezdnyy    70.9333 -179.6000   Russia    RU   RUS
# 3       ...    Zvezdnyy    70.9333 -179.6000   Russia    RU   RUS
# 4       ...    Zvezdnyy    70.9333 -179.6000   Russia    RU   RUS
# ...     ...         ...        ...       ...      ...   ...   ...
# 841589  ...        Suva   -18.1416  178.4419     Fiji    FJ   FJI
# 841590  ...        Suva   -18.1416  178.4419     Fiji    FJ   FJI
# 841591  ...        Suva   -18.1416  178.4419     Fiji    FJ   FJI
# 841592  ...        Suva   -18.1416  178.4419     Fiji    FJ   FJI
# 841593  ...        Suva   -18.1416  178.4419     Fiji    FJ   FJI
#
#                          admin_name  capital  population          id
# 0       Chukotskiy Avtonomnyy Okrug      NaN        10.0  1643877771
# 1       Chukotskiy Avtonomnyy Okrug      NaN        10.0  1643877771
# 2       Chukotskiy Avtonomnyy Okrug      NaN        10.0  1643877771
# 3       Chukotskiy Avtonomnyy Okrug      NaN        10.0  1643877771
# 4       Chukotskiy Avtonomnyy Okrug      NaN        10.0  1643877771
# ...                             ...      ...         ...         ...
# 841589                         Rewa  primary    185913.0  1242615095
# 841590                         Rewa  primary    185913.0  1242615095
# 841591                         Rewa  primary    185913.0  1242615095
# 841592                         Rewa  primary    185913.0  1242615095
# 841593                         Rewa  primary    185913.0  1242615095
#
# [843193 rows x 88 columns]

# %%
len(merged["city"].unique())
# Out:
# 8363

# %%
zones_df[zones_df["city"] == "Bogotá"]
# Out:
#       city city_ascii     lat      lng   country iso2 iso3 admin_name  \
# 63  Bogotá     Bogota  4.7111 -74.0722  Colombia   CO  COL     Bogotá
#
#     capital  population          id                   geometry
# 63  primary   7968095.0  1170483426  POINT (-74.07220 4.71110)

# %%
merged[(merged["lat_left"] == 4.5) & (merged["lon"] == -74.5)]
# Out:
#          lon  lat_left  time  CLOUD_OD_11  ALLSKY_SFC_SW_DWN_19  CLOUD_OD_02  \
# 246805 -74.5       4.5   0.0     3.953125            536.117188     3.750000
# 246806 -74.5       4.5   1.0     5.156250            500.820312     4.429688
# 246807 -74.5       4.5   2.0     8.062500            448.109375     5.484375
# 246808 -74.5       4.5   3.0    14.171875            480.992188     3.773438
# 246809 -74.5       4.5   4.0    11.898438            490.460938     4.476562
# 246810 -74.5       4.5   5.0    10.734375            485.476562     3.875000
# 246811 -74.5       4.5   6.0     6.664062            472.953125     3.617188
# 246812 -74.5       4.5   7.0     8.703125            479.523438     3.703125
# 246813 -74.5       4.5   8.0     9.960938            500.976562     4.117188
# 246814 -74.5       4.5   9.0     8.000000            458.320312     5.179688
# 246815 -74.5       4.5  10.0     9.140625            470.523438     4.289062
# 246816 -74.5       4.5  11.0     8.218750            456.351562     3.625000
# 246817 -74.5       4.5   NaN     8.726562            481.531250     4.195312
#
#         CLOUD_OD_05  CLOUD_AMT_11  ALLSKY_SFC_SW_DWN_04  ALLSKY_SFC_SW_DWN_01  \
# 246805     3.632812     53.046875                   0.0                   0.0
# 246806     4.828125     71.203125                   0.0                   0.0
# 246807     5.601562     79.531250                   0.0                   0.0
# 246808     5.429688     88.835938                   0.0                   0.0
# 246809     4.750000     78.648438                   0.0                   0.0
# 246810     5.093750     73.648438                   0.0                   0.0
# 246811     3.687500     73.820312                   0.0                   0.0
# 246812     4.828125     85.460938                   0.0                   0.0
# 246813     4.085938     66.437500                   0.0                   0.0
# 246814     4.804688     69.687500                   0.0                   0.0
# 246815     3.843750     65.015625                   0.0                   0.0
# 246816     4.078125     61.890625                   0.0                   0.0
# 246817     4.554688     72.265625                   0.0                   0.0
#
#         ...  city_ascii  lat_right      lng   country  iso2  iso3  \
# 246805  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246806  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246807  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246808  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246809  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246810  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246811  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246812  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246813  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246814  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246815  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246816  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
# 246817  ...    Anapoima     4.5503 -74.5361  Colombia    CO   COL
#
#           admin_name  capital  population          id
# 246805  Cundinamarca    minor     14519.0  1170450555
# 246806  Cundinamarca    minor     14519.0  1170450555
# 246807  Cundinamarca    minor     14519.0  1170450555
# 246808  Cundinamarca    minor     14519.0  1170450555
# 246809  Cundinamarca    minor     14519.0  1170450555
# 246810  Cundinamarca    minor     14519.0  1170450555
# 246811  Cundinamarca    minor     14519.0  1170450555
# 246812  Cundinamarca    minor     14519.0  1170450555
# 246813  Cundinamarca    minor     14519.0  1170450555
# 246814  Cundinamarca    minor     14519.0  1170450555
# 246815  Cundinamarca    minor     14519.0  1170450555
# 246816  Cundinamarca    minor     14519.0  1170450555
# 246817  Cundinamarca    minor     14519.0  1170450555
#
# [13 rows x 88 columns]
